# %% [markdown]
# <a href="https://colab.research.google.com/github/bxrna7/Ficheiro/blob/main/Aula_01_Python_CTFE_FIAP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Arquivo Python = .py

#Arquvio Jupyter Notebook Python = .ipynb

# Built-in Function ---> função pré instalada

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# ***MarkDown***

# %%
#  .md

# %%
x = 10
pi = 3.14
y = True

type(x)
type(pi)
type(y)
# Out:
# bool

# %%
a = "Daniel"
b = 4.567
c = 10
d = False
# == --> comparação

# %%
a, b, c, d
# Out:
# ('Daniel', 4.567, 10, False)

# %%
num1 = int(input("Valor 1: "))
num2 = float(input("Valor 2: "))
# Out:
# Valor 1: 2
# Valor 2: 3.14

# %%
num1 + num2
# Out:
# 5.140000000000001
