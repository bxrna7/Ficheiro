# %% [markdown]
# <a href="https://colab.research.google.com/github/bxrna7/Ficheiro/blob/main/CalculoMediaNotasFiap.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Calcular média das notas FIAP

def media():
