# %% [markdown]
# <a href="https://colab.research.google.com/github/bxrna7/Ficheiro/blob/main/Python_FIAP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Arquivo Python = .py

#Arquvio Notebook Python = .ipynb

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# ***MarkDown***

# %%
#  .md

# %%
x = 10
pi = 3.14
y = True

type(x)
type(pi)
type(y)
# Out:
# bool
